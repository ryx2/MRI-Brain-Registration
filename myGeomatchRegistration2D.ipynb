# %% [markdown]
# # CNNGeometric demo notebook
# This notebook shows how to run a trained model on a given image pair

# %% [markdown]
# ## Imports

# %%
from __future__ import print_function, division
import os
import argparse
import torch
import torch.nn as nn
from torch.utils.data import Dataset, DataLoader
from model.cnn_geometric_model import CNNGeometric
from data.pf_dataset import PFDataset
from data.download_datasets import download_PF_willow
from image.normalization import NormalizeImageDict, normalize_image
from util.torch_util import BatchTensorToVars, str_to_bool
from geotnf.transformation import GeometricTnf
from geotnf.point_tnf import *
import matplotlib.pyplot as plt
from skimage import io
import warnings
from torchvision.transforms import Normalize

warnings.filterwarnings('ignore')

# %% [markdown]
# ## Parameters

# %%
model_aff_path = 'best_pascal_checkpoint_adam_affine_grid_loss.pth.tar'
model_tps_path = 'best_pascal_checkpoint_adam_tps_grid_loss.pth.tar'

# %% [markdown]
# ## Load models

# %%
use_cuda = torch.cuda.is_available()
do_aff = not model_aff_path==''
do_tps = not model_tps_path==''

# Create model
print('Creating CNN model...')
if do_aff:
    model_aff = CNNGeometric(use_cuda=use_cuda,geometric_model='affine')
if do_tps:
    model_tps = CNNGeometric(use_cuda=use_cuda,geometric_model='tps')
    
# Load trained weights
print('Loading trained model weights...')
if do_aff:
    checkpoint = torch.load(model_aff_path, map_location=lambda storage, loc: storage)
    model_aff.load_state_dict(checkpoint['state_dict'])
if do_tps:
    checkpoint = torch.load(model_tps_path, map_location=lambda storage, loc: storage)
    model_tps.load_state_dict(checkpoint['state_dict'])
# Out:
# Creating CNN model...
# Loading trained model weights...

# %% [markdown]
# ## Create image transformers

# %%
tpsTnf = GeometricTnf(geometric_model='tps', use_cuda=use_cuda)
affTnf = GeometricTnf(geometric_model='affine', use_cuda=use_cuda)

# %% [markdown]
# ## Load and preprocess images

# %%
resizeCNN = GeometricTnf(out_h=240, out_w=240, use_cuda = False) 
normalizeTnf = Normalize(mean=[0.485, 0.456, 0.406], std=[0.229, 0.224, 0.225])

def preprocess_image(image):
    if(len(image.shape)==2): # if the image was gray scale, make it rgb by cloning the image 3x
        image=np.stack((image,)*3,axis=2)
    dims = image.shape
    if(dims[2]==3): # add the last axis if there aren't enough dimensions
        image=np.concatenate((image,np.expand_dims(np.full((dims[0],dims[1]),255),axis=2)),axis=2)
    # convert to torch Variable
    image = np.expand_dims(image.transpose((2,0,1)),0)
    image = torch.Tensor(image.astype(np.float32)/255.0)
    image_var = Variable(image,requires_grad=False)

    # Resize image using bilinear sampling with identity affine tnf
    image_var = resizeCNN(image_var)
    
    # Normalize image

    image_var = normalize_image(image_var[:,:3,:,:])
    
    return image_var

# %%
#source_image = img0
#target_image = img1
source_image_path='brain_images/brain58.png'
target_image_path='brain_images/adhd200brain58.png'
source_image = io.imread(source_image_path)
target_image = io.imread(target_image_path)
#issue here is that the program expects a rgba image, aka 4d image, grayscale is only 2d

# %%
source_image_var = preprocess_image(source_image)
target_image_var = preprocess_image(target_image)

# # convert to torch Variable
# image = np.expand_dims(source_image.transpose((2,0,1)),0)
# image = torch.Tensor(image.astype(np.float32)/255.0)
# image_var = Variable(image,requires_grad=False)

# # Resize image using bilinear sampling with identity affine tnf
# image_var = resizeCNN(image_var)
# image = image_var[:,:3,:,:]
# im_size = image.size()
# mean=torch.FloatTensor([0.485, 0.456, 0.406]).unsqueeze(1).unsqueeze(2)
# std=torch.FloatTensor([0.229, 0.224, 0.225]).unsqueeze(1).unsqueeze(2)
# print(mean.size())
# print(im_size)

# %%
if use_cuda:
    source_image_var = source_image_var.cuda()
    target_image_var = target_image_var.cuda()

batch = {'source_image': source_image_var, 'target_image':target_image_var}

resizeTgt = GeometricTnf(out_h=target_image.shape[0], out_w=target_image.shape[1], use_cuda = use_cuda)

# %% [markdown]
# ## Evaluate model

# %%
if do_aff:
    model_aff.eval()
if do_tps:
    model_tps.eval()

# Evaluate models
if do_aff:
    theta_aff=model_aff(batch)
    warped_image_aff = affTnf(batch['source_image'],theta_aff.view(-1,2,3))

if do_tps:
    theta_tps=model_tps(batch)
    warped_image_tps = tpsTnf(batch['source_image'],theta_tps)

if do_aff and do_tps:
    theta_aff_tps=model_tps({'source_image': warped_image_aff, 'target_image': batch['target_image']})        
    warped_image_aff_tps = tpsTnf(warped_image_aff,theta_aff_tps)

# %% [markdown]
# ## Process result

# %%
# Un-normalize images and convert to numpy
if do_aff:
    warped_image_aff_np = normalize_image(resizeTgt(warped_image_aff),forward=False).data.squeeze(0).transpose(0,1).transpose(1,2).cpu().numpy()

if do_tps:
    warped_image_tps_np = normalize_image(resizeTgt(warped_image_tps),forward=False).data.squeeze(0).transpose(0,1).transpose(1,2).cpu().numpy()

if do_aff and do_tps:
    warped_image_aff_tps_np = normalize_image(resizeTgt(warped_image_aff_tps),forward=False).data.squeeze(0).transpose(0,1).transpose(1,2).cpu().numpy()

# %% [markdown]
# ## Display

# %%
N_subplots = 2+int(do_aff)+int(do_tps)+int(do_aff and do_tps)
fig, axs = plt.subplots(1,N_subplots)
axs[0].imshow(source_image)
axs[0].set_title('src')
axs[1].imshow(target_image)
axs[1].set_title('tgt')
subplot_idx = 2
if do_aff:
    axs[subplot_idx].imshow(warped_image_aff_np)
    axs[subplot_idx].set_title('aff')
    subplot_idx +=1 
if do_tps:
    axs[subplot_idx].imshow(warped_image_tps_np)
    axs[subplot_idx].set_title('tps')
    subplot_idx +=1 
if do_aff and do_tps:
    axs[subplot_idx].imshow(warped_image_aff_tps_np)
    axs[subplot_idx].set_title('aff+tps')

for i in range(N_subplots):
    axs[i].axis('off')

fig.set_dpi(175)
plt.show()

# %%
# display the the results: display the difference between the images
fig, axs = plt.subplots(1,3)
axs[0].imshow(source_image-target_image)
axs[0].set_title('original difference')
axs[1].imshow(warped_image_aff_tps_np[35:220,15:230,0]*255-target_image[35:220,15:230])
axs[1].set_title('new difference')
axs[2].imshow(warped_image_aff_tps_np[35:220,15:230,0]*255-source_image[35:220,15:230])
axs[2].set_title('src to warped dif')
fig.set_dpi(150)
plt.show()

# %%
print(target_image[255,100])
print(warped_image_aff_tps_np[255,110,0]*255)
# Out:
# 0
# 123.675003648

# %%
# why does workingBrain0,1.png work but not brain1,2.png
# %matplotlib inline
source_image = io.imread('workingBrain0.png')
target_image = io.imread('workingBrain1.png')
print(target_image[500,509,3])
# plt.imshow(target_image)

source_image = io.imread('brain1.png')
target_image = io.imread('brain2.png')
print(source_image[130,101])
# Out:
# 255
# 90
